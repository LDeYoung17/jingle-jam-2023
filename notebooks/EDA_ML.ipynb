# %%
import pandas as pd
from collections import namedtuple

# %%
df_cities = pd.read_csv('/Users/admin/Desktop/GitHub/new_repos/jingle-jam-2023/cities15000.csv', encoding = "iso-8859-1")

# %%
display(df_cities.sample(10))
df_cities.info()
# Out:
#       geonameid                 name            asciiname  \
# 2926    3892892          Curanilahue          Curanilahue
# 15767   1705190              Lumbang              Lumbang
# 9491    1258843            Rjmahal             Rajmahal
# 15271   3149563            Kongsberg            Kongsberg
# 21311   4950065                Salem                Salem
# 10696   1272648            Dibrugarh            Dibrugarh
# 18683   1153090       Kamphaeng Phet       Kamphaeng Phet
# 18933   2467521  La Sebala du Mornag  La Sebala du Mornag
# 4663    2857904     Oer-Erkenschwick     Oer-Erkenschwick
# 8519    1624647          Tasikmalaya          Tasikmalaya
#
#                                           alternatenames   latitude  \
# 2926   Curanilahue,Kuranilaueh,Kuranilave,ku la ni la...  -37.47793
# 15767                                     Lumban,Lumbang    14.2973
# 9491                                  Rajmahal,Rjmahal   25.05303
# ...

# %%
#df_cities = df_cities.dropna()
#df_cities.info()

# %%
print(df_cities['longitude'].isna().count())
df_cities['longitude'] = df_cities['latitude'].dropna()
print(df_cities['longitude'].isna().count())
df_cities.info()
# Out:
# 23469
# 23469
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23469 entries, 0 to 23468
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   geonameid          23468 non-null  object
#  1   name               23469 non-null  object
#  2   asciiname          23469 non-null  object
#  3   alternatenames     21460 non-null  object
#  4   latitude           23467 non-null  object
#  5   longitude          23467 non-null  object
#  6   feature class      23466 non-null  object
#  7   feature code       23467 non-null  object
#  8   country code       23454 non-null  object
#  9   cc2                238 non-null    object
#  10  admin1 code        23459 non-null  object
#  11  admin2 code        16271 non-null  object
#  12  admin3 code        7118 non-null   object
#  13  admin4 code        2225 non-null   object
#  14  population         23467 non-null  object
# ...

# %%
df_cities_lat_long = df_cities.groupby(['latitude', 'longitude'])['name'].max().reset_index().rename(columns={0: 'latitude', 1: 'longitude', 'name': 'name'})

display(df_cities_lat_long.sample(10))

df_cities_lat_long.info()
# Out:
#         latitude  longitude          name
# 17373   47.80527   47.80527  Bothell West
# 21080   55.17719   55.17719     Ashington
# 1075   -22.54417  -22.54417   Barra Mansa
# 2871     -7.9908    -7.9908    Wongsorejo
# 5877    20.48273   20.48273      Kranja
# 7187    25.31642   25.31642         Hilsa
# 14214    40.9805    40.9805    Farmington
# 21492   56.99719   56.99719       Ivanovo
# 8327    28.63528   28.63528     Chihuahua
# 22667    9.58893    9.58893        Kabala
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22773 entries, 0 to 22772
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   22773 non-null  object
#  1   longitude  22773 non-null  object
#  2   name       22773 non-null  object
# dtypes: object(3)
# memory usage: 533.9+ KB
